# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = 10
y = 10
r = 5

def generate_disc(x,y,r):
    
    x_c = r*np.cos( np.linspace(-np.pi,np.pi,100))+x
    y_c = r*np.sin( np.linspace(-np.pi,np.pi,100))+y
    
    x_c = np.append(x_c,x).reshape(-1,1)
    y_c = np.append(y_c,y).reshape(-1,1)

    triangles = []
    for i in range(len(x_c)-1):
        #print(i,i+1,len(x_c))
        j = len(x_c)-1
        triangles.append((i,i+1,len(x_c)))
    
    triangles = np.array(triangles)
    vertex    = np.concatenate((x_c , y_c,x_c*0),axis = 1)
    
    return vertex , triangles

# %%
vertex,triangles = generate_disc(x,y,r)
vertex
triangles
# Out:
# array([[  0,   1, 101],
#        [  1,   2, 101],
#        [  2,   3, 101],
#        [  3,   4, 101],
#        [  4,   5, 101],
#        [  5,   6, 101],
#        [  6,   7, 101],
#        [  7,   8, 101],
#        [  8,   9, 101],
#        [  9,  10, 101],
#        [ 10,  11, 101],
#        [ 11,  12, 101],
#        [ 12,  13, 101],
#        [ 13,  14, 101],
#        [ 14,  15, 101],
#        [ 15,  16, 101],
#        [ 16,  17, 101],
#        [ 17,  18, 101],
#        [ 18,  19, 101],
#        [ 19,  20, 101],
#        [ 20,  21, 101],
#        [ 21,  22, 101],
#        [ 22,  23, 101],
#        [ 23,  24, 101],
#        [ 24,  25, 101],
#        [ 25,  26, 101],
#        [ 26,  27, 101],
#        [ 27,  28, 101],
#        [ 28,  29, 101],
#        [ 29,  30, 101],
#        [ 30,  31, 101],
#        [ 31,  32, 101],
#        [ 32,  33, 101],
#        [ 33,  34, 101],
#        [ 34,  35, 101],
#        [ 35,  36, 101],
#        [ 36,  37, 101],
#        [ 37,  38, 101],
#        [ 38,  39, 101],
#        [ 39,  40, 101],
#        [ 40,  41, 101],
#        [ 41,  42, 101],
#        [ 42,  43, 101],
#        [ 43,  44, 101],
#        [ 44,  45, 101],
#        [ 45,  46, 101],
#        [ 46,  47, 101],
#        [ 47,  48, 101],
#        [ 48,  49, 101],
#        [ 49,  50, 101],
#        [ 50,  51, 101],
#        [ 51,  52, 101],
#        [ 52,  53, 101],
#        [ 53,  54, 101],
#        [ 54,  55, 101],
#        [ 55,  56, 101],
#        [ 56,  57, 101],
#        [ 57,  58, 101],
#        [ 58,  59, 101],
#        [ 59,  60, 101],
#        [ 60,  61, 101],
#        [ 61,  62, 101],
#        [ 62,  63, 101],
#        [ 63,  64, 101],
#        [ 64,  65, 101],
#        [ 65,  66, 101],
#        [ 66,  67, 101],
#        [ 67,  68, 101],
#        [ 68,  69, 101],
#        [ 69,  70, 101],
#        [ 70,  71, 101],
#        [ 71,  72, 101],
#        [ 72,  73, 101],
#        [ 73,  74, 101],
#        [ 74,  75, 101],
#        [ 75,  76, 101],
#        [ 76,  77, 101],
#        [ 77,  78, 101],
#        [ 78,  79, 101],
#        [ 79,  80, 101],
#        [ 80,  81, 101],
#        [ 81,  82, 101],
#        [ 82,  83, 101],
#        [ 83,  84, 101],
#        [ 84,  85, 101],
#        [ 85,  86, 101],
#        [ 86,  87, 101],
#        [ 87,  88, 101],
#        [ 88,  89, 101],
#        [ 89,  90, 101],
#        [ 90,  91, 101],
#        [ 91,  92, 101],
#        [ 92,  93, 101],
#        [ 93,  94, 101],
#        [ 94,  95, 101],
#        [ 95,  96, 101],
#        [ 96,  97, 101],
#        [ 97,  98, 101],
#        [ 98,  99, 101],
#        [ 99, 100, 101]])

# %%
triangles = []
for i in range(len(x_c)-1):
    print(i,i+1,len(x_c))
    j = len(x_c)-1
    triangles.append((i,i+1,len(x_c)))
    
    plt.plot([x_c[i],x_c[i+1],x_c[j],x_c[i]], 
             [y_c[i],y_c[i+1],y_c[j],y_c[i]],
             c=c)
# Out:
# 0 1 101
# 1 2 101
# 2 3 101
# 3 4 101
# 4 5 101
# 5 6 101
# 6 7 101
# 7 8 101
# 8 9 101
# 9 10 101
# 10 11 101
# 11 12 101
# 12 13 101
# 13 14 101
# 14 15 101
# 15 16 101
# 16 17 101
# 17 18 101
# 18 19 101
# 19 20 101
# 20 21 101
# 21 22 101
# 22 23 101
# 23 24 101
# 24 25 101
# 25 26 101
# 26 27 101
# 27 28 101
# 28 29 101
# 29 30 101
# 30 31 101
# 31 32 101
# 32 33 101
# 33 34 101
# 34 35 101
# 35 36 101
# 36 37 101
# 37 38 101
# 38 39 101
# 39 40 101
# 40 41 101
# 41 42 101
# 42 43 101
# 43 44 101
# 44 45 101
# 45 46 101
# 46 47 101
# 47 48 101
# 48 49 101
# 49 50 101
# 50 51 101
# 51 52 101
# 52 53 101
# 53 54 101
# 54 55 101
# 55 56 101
# 56 57 101
# 57 58 101
# 58 59 101
# 59 60 101
# 60 61 101
# 61 62 101
# 62 63 101
# 63 64 101
# 64 65 101
# 65 66 101
# 66 67 101
# 67 68 101
# 68 69 101
# 69 70 101
# 70 71 101
# 71 72 101
# 72 73 101
# 73 74 101
# 74 75 101
# 75 76 101
# 76 77 101
# 77 78 101
# 78 79 101
# 79 80 101
# 80 81 101
# 81 82 101
# 82 83 101
# 83 84 101
# 84 85 101
# 85 86 101
# 86 87 101
# 87 88 101
# 88 89 101
# 89 90 101
# 90 91 101
# 91 92 101
# 92 93 101
# 93 94 101
# 94 95 101
# 95 96 101
# 96 97 101
# 97 98 101
# 98 99 101
# 99 100 101

# %%
triangles = []
for i in range(len(x_c)-1):
    print(i,i+1,len(x_c))
    j = len(x_c)-1
    triangles.append((i,i+1,len(x_c)))
# Out:
# [(0, 1, 101),
#  (1, 2, 101),
#  (2, 3, 101),
#  (3, 4, 101),
#  (4, 5, 101),
#  (5, 6, 101),
#  (6, 7, 101),
#  (7, 8, 101),
#  (8, 9, 101),
#  (9, 10, 101),
#  (10, 11, 101),
#  (11, 12, 101),
#  (12, 13, 101),
#  (13, 14, 101),
#  (14, 15, 101),
#  (15, 16, 101),
#  (16, 17, 101),
#  (17, 18, 101),
#  (18, 19, 101),
#  (19, 20, 101),
#  (20, 21, 101),
#  (21, 22, 101),
#  (22, 23, 101),
#  (23, 24, 101),
#  (24, 25, 101),
#  (25, 26, 101),
#  (26, 27, 101),
#  (27, 28, 101),
#  (28, 29, 101),
#  (29, 30, 101),
#  (30, 31, 101),
#  (31, 32, 101),
#  (32, 33, 101),
#  (33, 34, 101),
#  (34, 35, 101),
#  (35, 36, 101),
#  (36, 37, 101),
#  (37, 38, 101),
#  (38, 39, 101),
#  (39, 40, 101),
#  (40, 41, 101),
#  (41, 42, 101),
#  (42, 43, 101),
#  (43, 44, 101),
#  (44, 45, 101),
#  (45, 46, 101),
#  (46, 47, 101),
#  (47, 48, 101),
#  (48, 49, 101),
#  (49, 50, 101),
#  (50, 51, 101),
#  (51, 52, 101),
#  (52, 53, 101),
#  (53, 54, 101),
#  (54, 55, 101),
#  (55, 56, 101),
#  (56, 57, 101),
#  (57, 58, 101),
#  (58, 59, 101),
#  (59, 60, 101),
#  (60, 61, 101),
#  (61, 62, 101),
#  (62, 63, 101),
#  (63, 64, 101),
#  (64, 65, 101),
#  (65, 66, 101),
#  (66, 67, 101),
#  (67, 68, 101),
#  (68, 69, 101),
#  (69, 70, 101),
#  (70, 71, 101),
#  (71, 72, 101),
#  (72, 73, 101),
#  (73, 74, 101),
#  (74, 75, 101),
#  (75, 76, 101),
#  (76, 77, 101),
#  (77, 78, 101),
#  (78, 79, 101),
#  (79, 80, 101),
#  (80, 81, 101),
#  (81, 82, 101),
#  (82, 83, 101),
#  (83, 84, 101),
#  (84, 85, 101),
#  (85, 86, 101),
#  (86, 87, 101),
#  (87, 88, 101),
#  (88, 89, 101),
#  (89, 90, 101),
#  (90, 91, 101),
#  (91, 92, 101),
#  (92, 93, 101),
#  (93, 94, 101),
#  (94, 95, 101),
#  (95, 96, 101),
#  (96, 97, 101),
#  (97, 98, 101),
#  (98, 99, 101),
#  (99, 100, 101)]
